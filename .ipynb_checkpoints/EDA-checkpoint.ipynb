# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Sau khi hoàn thành phần tiền xử lí dữ liệu, dữ liệu đã được làm sạch giúp ta trả lời một số câu hỏi chính xác và rõ ràng hơn.
# ###### Đầu tiên, import các thư viện cần thiết

# %%
import pandas as pd

# %% [markdown]
# ###### Load data

# %%
steam_df = pd.read_csv('processed_data.csv')
steam_df.head()
# Out:
#                                   Title  withDLC  isMature         Developer  \
# 0  Endless Monday: Dreams and Deadlines        0         0            hcnone
# 1               Papa's Freezeria Deluxe        0         0  Flipline Studios
# 2             Cats Hidden in Jingle Jam        0         0    Travellin Cats
# 3                An Arcade Full of Cats        1         0           Devcats
# 4                                    Ib        0         0             kouri
#
#           Publisher  PositiveReviews  TotalReviews  NegativeReviews     Price  \
# 0            hcnone              737           737                0  142000.0
# 1  Flipline Studios             6514          6562               48   87500.0
# 2    Travellin Cats             5097          5108               11       0.0
# 3           Devcats             3018          3045               27       0.0
# 4           PLAYISM             3068          3098               30  150000.0
#
# ...

# %% [markdown]
# #### Câu hỏi 1: Xu hướng phát triển game qua các năm của các nhà phát triển như thế nào?
# Để trả lời câu hỏi này trước tiên ta sẽ xem xét có bao nhiêu nhà phát triển trong bộ dữ liệu, và các mốc thời gian cho toàn bộ các game.

# %%
steam_df.groupby('Developer')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 steam_df.groupby('Developer').values()
#
# File E:\Anaconda\envs\min_ds-env\lib\site-packages\pandas\core\groupby\groupby.py:1308, in GroupBy.__getattr__(self, attr)
#    1305 if attr in self.obj:
#    1306     return self[attr]
# -> 1308 raise AttributeError(
#    1309     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1310 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'values'
