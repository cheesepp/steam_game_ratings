# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Preprocessing
# </div>

# %% [markdown]
# <h2> Import thư viện cần thiết </h2>

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt

# %% [markdown]
# <h2>Đọc dữ liệu từ file <font color="blue">"steam_game.csv" </font></h2>

# %%
df = pd.read_csv('../data/steam_game.csv')
df.head(10)
# Out:
#               Title                                   Genre  \
# 0   Baldur's Gate 3                Adventure, RPG, Strategy
# 1  Counter-Strike 2                    Action, Free to Play
# 2    Lethal Company  Action, Adventure, Indie, Early Access
# 3    Cyberpunk 2077                                     RPG
# 4        ELDEN RING                             Action, RPG
# 5     Apex Legends™         Action, Adventure, Free to Play
# 6            Dota 2          Action, Strategy, Free to Play
# 7   Hogwarts Legacy                  Action, Adventure, RPG
# 8  Dead by Daylight                                  Action
# 9   Project Zomboid    Indie, RPG, Simulation, Early Access
#
#                                                 Tags  withDLC  isMature  \
# 0  RPG, Choices Matter, Story Rich, Character Cus...      1.0       1.0
# 1  FPS, Shooter, Multiplayer, Competitive, Action...      1.0       1.0
# 2  Online Co-Op, Horror, First-Person, Psychologi...      0.0       1.0
# 3  Cyberpunk, Open World, Nudity, RPG, Singleplay...      1.0       1.0
# 4  Souls-like, Dark Fantasy, Open World, RPG, Dif...      0.0       1.0
# 5  Free to Play, Battle Royale, Multiplayer, Shoo...      0.0       0.0
# 6  Free to Play, MOBA, Multiplayer, Strategy, eSp...      1.0       0.0
# 7  Magic, Fantasy, Open World, Singleplayer, Adve...      1.0       0.0
# 8  Horror, Survival Horror, Multiplayer, Online C...      1.0       1.0
# 9  Survival, Zombies, Open World, Open World Surv...      0.0       0.0
#
#                     Franchise   ReleaseDate                   Developer  \
# 0               Baldur's Gate   3 Aug, 2023              Larian Studios
# 1                         NaN  21 Aug, 2012                       Valve
# 2                         NaN  23 Oct, 2023                    Zeekerss
# 3                         NaN   9 Dec, 2020              CD PROJEKT RED
# 4  Bandai Namco Entertainment  24 Feb, 2022           FromSoftware Inc.
# 5                Apex Legends   4 Nov, 2020       Respawn Entertainment
# 6                        Dota   9 Jul, 2013                       Valve
# 7                    WB Games  10 Feb, 2023          Avalanche Software
# 8            Dead by Daylight  14 Jun, 2016  Behaviour Interactive Inc.
# 9                         NaN   8 Nov, 2013             The Indie Stone
#
#                     Publisher  \
# 0              Larian Studios
# 1                       Valve
# 2                    Zeekerss
# 3              CD PROJEKT RED
# 4           FromSoftware Inc.
# 5             Electronic Arts
# 6                       Valve
# 7          Warner Bros. Games
# 8  Behaviour Interactive Inc.
# 9             The Indie Stone
#
#                                            Languages PositiveReviews  \
# 0  English, French, German, Spanish - Spain, Poli...       (498,632)
# 1  English, Czech, Danish, Dutch, Finnish, French...     (6,845,621)
# 2                                            English       (218,847)
# 3  English, French, Italian, German, Spanish - Sp...       (564,519)
# 4  English, French, Italian, German, Spanish - Sp...       (688,189)
# 5  English, French, Italian, German, Spanish - Sp...       (613,541)
# 6  English, Bulgarian, Czech, Danish, Dutch, Finn...     (1,758,564)
# 7  English, French, Italian, German, Spanish - Sp...       (225,796)
# 8  English, French, Italian, German, Spanish - Sp...       (565,863)
# 9  English, French, Italian, German, Spanish - Sp...       (246,145)
#
#   TotalReviews NegativeReviews  OriginalPrice DiscountPercent
# 0    (515,427)        (16,795)    990.000,00₫            -10%
# 1  (7,809,836)       (964,215)           Free             NaN
# 2    (222,992)         (4,145)    142.000,00₫             NaN
# 3    (697,970)       (133,451)    990.000,00₫            -50%
# 4    (744,999)        (56,810)    898.000,00₫            -40%
# 5    (773,739)       (160,198)           Free             NaN
# 6  (2,142,374)       (383,810)           Free             NaN
# 7    (245,819)        (20,023)  1.290.000,00₫            -50%
# 8    (704,111)       (138,248)    230.000,00₫            -65%
# 9    (261,675)        (15,530)    260.000,00₫            -33%

# %% [markdown]
# <h2>Ta xem xét có tổng cộng bao nhiêu hàng và cột thuộc tính ở tập dữ liệu thô </h2>
# Nếu dữ liệu có trên 1000 dòng và phải có trên 5 cột thuộc tính thì dữ liệu mới đủ để tiến hành các bước khai thác, xây dựng mô hình học máy, học sâu, ...
#
# Ngược lại, dữ liệu quá ít, không đủ -> cần thu thập thêm dữ liệu

# %%
num_rows, num_cols = df.shape
print(f'Current shape of data: {df.shape}')
if (num_rows > 100) & (num_cols > 5):
    print('Data is good !')
else:
    print('You should collect more data')
# Out:
# Current shape of data: (9583, 15)
# Data is good !

# %% [markdown]
# ### Ta xem xét ý nghĩa của từng cột dữ liệu
# 1. Title: Tên trò chơi điện tử trên website steam
# 2. Genre: Thể loại trò chơi
# 3. Tags: các nhãn trò chơi mà người dùng(người chơi) gắn cho trò chơi
# 4. withDLC: trò chơi có kèm theo các downloadable content hay không ?
# 5. isMature: trò chơi có được gán nhãn không phù hợp cho trẻ nhỏ hay không?
# 6. Franchise: tên thương hiệu của trò chơi
# 7. ReleaseDate: Ngày phát hành của trò chơi
# 8. Developer: Nhà phát triển trò chơi
# 9. Publisher: Nhà phát hành trò chơi
# 10. Languages: Các ngôn ngữ được hỗ trợ trong trò chơi
# 11. PositiveReviews: Số đánh giá tích cực về trò chơi
# 12. TotalReviews: Tổng số đánh giá của người chơi về trò chơi
# 13. NegativeReviews: Số đánh giá tiêu cực về trò chơi
# 14. OriginalPrice: Giá bán gốc của trò chơi
# 15. DiscountPercent: Giảm giá áp dụng trên giá gốc(%)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9583 entries, 0 to 9582
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            9531 non-null   object
#  1   Genre            9515 non-null   object
#  2   Tags             9531 non-null   object
#  3   withDLC          9583 non-null   float64
#  4   isMature         9583 non-null   float64
#  5   Franchise        4576 non-null   object
#  6   ReleaseDate      9526 non-null   object
#  7   Developer        9525 non-null   object
#  8   Publisher        9509 non-null   object
#  9   Languages        9531 non-null   object
#  10  PositiveReviews  9518 non-null   object
#  11  TotalReviews     9518 non-null   object
#  12  NegativeReviews  9518 non-null   object
#  13  OriginalPrice    9583 non-null   object
#  14  DiscountPercent  8220 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# Kiểm tra xem mỗi feature chiếm nhiêu % missing value:

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# Title               0.542628
# Genre               0.709590
# Tags                0.542628
# withDLC             0.000000
# isMature            0.000000
# Franchise          52.248774
# ReleaseDate         0.594803
# Developer           0.605238
# Publisher           0.772201
# Languages           0.542628
# PositiveReviews     0.678284
# TotalReviews        0.678284
# NegativeReviews     0.678284
# OriginalPrice       0.000000
# DiscountPercent    14.223103
# dtype: float64

# %% [markdown]
# ##### Loại bỏ những dòng dữ liệu có *"Title"* là Nan value

# %%
df.dropna(subset = ['Title'], inplace = True)
df
# Out:
#                  Title                                              Genre  \
# 0      Baldur's Gate 3                           Adventure, RPG, Strategy
# 1     Counter-Strike 2                               Action, Free to Play
# 2       Lethal Company             Action, Adventure, Indie, Early Access
# 3       Cyberpunk 2077                                                RPG
# 4           ELDEN RING                                        Action, RPG
# ...                ...                                                ...
# 9578              命运联结  Action, Adventure, Casual, Massively Multiplay...
# 9579          HeXen II                                             Action
# 9580   Royal Revolt II  Action, Free to Play, Massively Multiplayer, R...
# 9581     Time Commando                                             Action
# 9582       DREAM LOGIC                                   Adventure, Indie
#
#                                                    Tags  withDLC  isMature  \
# 0     RPG, Choices Matter, Story Rich, Character Cus...      1.0       1.0
# 1     FPS, Shooter, Multiplayer, Competitive, Action...      1.0       1.0
# 2     Online Co-Op, Horror, First-Person, Psychologi...      0.0       1.0
# 3     Cyberpunk, Open World, Nudity, RPG, Singleplay...      1.0       1.0
# 4     Souls-like, Dark Fantasy, Open World, RPG, Dif...      0.0       1.0
# ...                                                 ...      ...       ...
# 9578  Casual, Adventure, Action, Strategy, RPG, Acti...      0.0       0.0
# 9579  Action, FPS, Classic, Fantasy, Gothic, Dark Fa...      0.0       0.0
# 9580  Action RPG, Tower Defense, Strategy, Massively...      0.0       0.0
# 9581  Beat 'em up, Combat, 1990's, Side Scroller, Ma...      0.0       0.0
# 9582  Adventure, Psychological Horror, Atmospheric, ...      0.0       1.0
#
#                        Franchise   ReleaseDate          Developer  \
# 0                  Baldur's Gate   3 Aug, 2023     Larian Studios
# 1                            NaN  21 Aug, 2012              Valve
# 2                            NaN  23 Oct, 2023           Zeekerss
# 3                            NaN   9 Dec, 2020     CD PROJEKT RED
# 4     Bandai Namco Entertainment  24 Feb, 2022  FromSoftware Inc.
# ...                          ...           ...                ...
# 9578                         NaN  16 Nov, 2023               命运联结
# 9579                         NaN  27 Mar, 1998     Raven Software
# 9580                         NaN  19 May, 2021         Flaregames
# 9581                         NaN  31 Jul, 1996             [2.21]
# 9582                         NaN   6 Sep, 2022    Teleopsia Games
#
#               Publisher                                          Languages  \
# 0        Larian Studios  English, French, German, Spanish - Spain, Poli...
# 1                 Valve  English, Czech, Danish, Dutch, Finnish, French...
# 2              Zeekerss                                            English
# 3        CD PROJEKT RED  English, French, Italian, German, Spanish - Sp...
# 4     FromSoftware Inc.  English, French, Italian, German, Spanish - Sp...
# ...                 ...                                                ...
# 9578               命运联结                        English, Simplified Chinese
# 9579        id Software                                            English
# 9580         Flaregames  English, French, Italian, German, Spanish - Sp...
# 9581             [2.21]                                            English
# 9582    Teleopsia Games                                            English
#
#      PositiveReviews TotalReviews NegativeReviews OriginalPrice  \
# 0          (498,632)    (515,427)        (16,795)   990.000,00₫
# 1        (6,845,621)  (7,809,836)       (964,215)          Free
# 2          (218,847)    (222,992)         (4,145)   142.000,00₫
# 3          (564,519)    (697,970)       (133,451)   990.000,00₫
# 4          (688,189)    (744,999)        (56,810)   898.000,00₫
# ...              ...          ...             ...           ...
# 9578              84          101              17          Free
# 9579             372          453              81   112.500,00₫
# 9580             142          191              49          Free
# 9581              57           61               4    87.500,00₫
# 9582             221          246              25    73.500,00₫
#
#      DiscountPercent
# 0               -10%
# 1                NaN
# 2                NaN
# 3               -50%
# 4               -40%
# ...              ...
# 9578             NaN
# 9579            -70%
# 9580             NaN
# 9581             NaN
# 9582             NaN
#
# [9531 rows x 15 columns]

# %%
if df['Title'].isna().sum() == 0:
    print('Column Title is now good !')
# Out:
# Column Title is now good !

# %% [markdown]
# ##### Có thể thấy số giá bị thiếu ở cột *DiscountPercent* là quá nhiều (hơn 90%) nên ta sẽ tính lại giá trị ở cột *OriginalPrice* sau khi đã áp dụng giảm giá, đổi tên thành *Price* và xóa đi cột *DiscountPercent*

# %% [markdown]
# ##### Trước hết, ta sẽ chuyển tất cả giá trị với đơn vị tiền tệ "$" sang "VND", tiến hàng loại bỏ kí tự hiển thị đơn vị tiền tệ, đưa giá trị "Free" thành 0 ở cột *OriginalPrice*

# %%
def convert_price(price):
    if price == "Free":
        return 0.0
    elif '₫' in price:
        formatted_price = float(price[: -4].replace('₫', '').replace('.', '').replace(',', ''))
        return round(formatted_price, 2)
    elif '$' in price:
        usd_to_vnd = 24265
        formatted_price =  float(price.replace('$', '')) * usd_to_vnd
        return round(formatted_price, 2)

df['OriginalPrice'] = df['OriginalPrice'].apply(convert_price)

# %%
# for price in df['OriginalPrice']:
#     print(price)

# %%
def convert_discount(discount):
    if pd.isna(discount):
        return 0
    else:
        return float(discount.replace('-', '').replace('%', '')) * 0.01

df['DiscountPercent'] = df['DiscountPercent'].apply(convert_discount)

# %%
# for discount in df['DiscountPercent']:
#     print(discount)

# %%
def price_after_discount(x):
    discount_percent = x['DiscountPercent']
    if pd.isna(discount_percent):
        return x['OriginalPrice']
    else:
        return x['OriginalPrice'] * (1 - discount_percent)

df['DiscountedPrice'] = df.apply(price_after_discount, axis = 1)

# %%
df['DiscountedPrice']
# Out:
# 0       891000.0
# 1            0.0
# 2       142000.0
# 3       495000.0
# 4       538800.0
#           ...
# 9578         0.0
# 9579     33750.0
# 9580         0.0
# 9581     87500.0
# 9582     73500.0
# Name: DiscountedPrice, Length: 9531, dtype: float64

# %%
df.head(20)
# Out:
#                                         Title  \
# 0                             Baldur's Gate 3
# 1                            Counter-Strike 2
# 2                              Lethal Company
# 3                              Cyberpunk 2077
# 4                                  ELDEN RING
# 5                               Apex Legends™
# 6                                      Dota 2
# 7                             Hogwarts Legacy
# 8                            Dead by Daylight
# 9                             Project Zomboid
# 10                         Sons Of The Forest
# 11  Sekiro™: Shadows Die Twice - GOTY Edition
# 12                               It Takes Two
# 13                  The Elder Scrolls® Online
# 14                                 God of War
# 15                                 Remnant II
# 16                              Party Animals
# 17                             DAVE THE DIVER
# 18                         NARAKA: BLADEPOINT
# 19                                  Stellaris
#
#                                                 Genre  \
# 0                            Adventure, RPG, Strategy
# 1                                Action, Free to Play
# 2              Action, Adventure, Indie, Early Access
# 3                                                 RPG
# 4                                         Action, RPG
# 5                     Action, Adventure, Free to Play
# 6                      Action, Strategy, Free to Play
# 7                              Action, Adventure, RPG
# 8                                              Action
# 9                Indie, RPG, Simulation, Early Access
# 10  Action, Adventure, Indie, Simulation, Early Ac...
# 11                                  Action, Adventure
# 12                                  Action, Adventure
# 13      Action, Adventure, Massively Multiplayer, RPG
# 14                             Action, Adventure, RPG
# 15                             Action, Adventure, RPG
# 16                              Action, Casual, Indie
# 17          Adventure, Casual, Indie, RPG, Simulation
# 18           Action, Adventure, Massively Multiplayer
# 19                               Simulation, Strategy
#
#                                                  Tags  withDLC  isMature  \
# 0   RPG, Choices Matter, Story Rich, Character Cus...      1.0       1.0
# 1   FPS, Shooter, Multiplayer, Competitive, Action...      1.0       1.0
# 2   Online Co-Op, Horror, First-Person, Psychologi...      0.0       1.0
# 3   Cyberpunk, Open World, Nudity, RPG, Singleplay...      1.0       1.0
# 4   Souls-like, Dark Fantasy, Open World, RPG, Dif...      0.0       1.0
# 5   Free to Play, Battle Royale, Multiplayer, Shoo...      0.0       0.0
# 6   Free to Play, MOBA, Multiplayer, Strategy, eSp...      1.0       0.0
# 7   Magic, Fantasy, Open World, Singleplayer, Adve...      1.0       0.0
# 8   Horror, Survival Horror, Multiplayer, Online C...      1.0       1.0
# 9   Survival, Zombies, Open World, Open World Surv...      0.0       0.0
# 10  Survival, Open World, Multiplayer, Survival Ho...      0.0       1.0
# 11  Souls-like, Difficult, Action, Singleplayer, N...      0.0       1.0
# 12  Co-op, Multiplayer, Split Screen, Local Co-Op,...      0.0       0.0
# 13  RPG, MMORPG, Open World, Adventure, Fantasy, E...      1.0       1.0
# 14  Action, Singleplayer, Story Rich, Adventure, M...      0.0       1.0
# 15  Souls-like, Action, Adventure, RPG, Co-op, Thi...      1.0       1.0
# 16  Casual, Funny, Multiplayer, Cute, Party Game, ...      1.0       0.0
# 17  Pixel Graphics, Casual, Adventure, Management,...      1.0       0.0
# 18  Battle Royale, Multiplayer, Martial Arts, PvP,...      1.0       1.0
# 19  Space, Grand Strategy, Strategy, Sci-fi, 4X, E...      1.0       0.0
#
#                      Franchise   ReleaseDate                   Developer  \
# 0                Baldur's Gate   3 Aug, 2023              Larian Studios
# 1                          NaN  21 Aug, 2012                       Valve
# 2                          NaN  23 Oct, 2023                    Zeekerss
# 3                          NaN   9 Dec, 2020              CD PROJEKT RED
# 4   Bandai Namco Entertainment  24 Feb, 2022           FromSoftware Inc.
# 5                 Apex Legends   4 Nov, 2020       Respawn Entertainment
# 6                         Dota   9 Jul, 2013                       Valve
# 7                     WB Games  10 Feb, 2023          Avalanche Software
# 8             Dead by Daylight  14 Jun, 2016  Behaviour Interactive Inc.
# 9                          NaN   8 Nov, 2013             The Indie Stone
# 10                         NaN  23 Feb, 2023          Endnight Games Ltd
# 11                         NaN  21 Mar, 2019                FromSoftware
# 12                EA Originals  25 Mar, 2021                   Hazelight
# 13           The Elder Scrolls   4 Apr, 2014      ZeniMax Online Studios
# 14         PlayStation Studios  14 Jan, 2022         Santa Monica Studio
# 15                         NaN  25 Jul, 2023               Gunfire Games
# 16                         NaN  20 Sep, 2023              Recreate Games
# 17                         NaN  28 Jun, 2023                  MINTROCKET
# 18                         NaN  11 Aug, 2021            24 Entertainment
# 19                   Stellaris   9 May, 2016  Paradox Development Studio
#
#                                 Publisher  \
# 0                          Larian Studios
# 1                                   Valve
# 2                                Zeekerss
# 3                          CD PROJEKT RED
# 4                       FromSoftware Inc.
# 5                         Electronic Arts
# 6                                   Valve
# 7                      Warner Bros. Games
# 8              Behaviour Interactive Inc.
# 9                         The Indie Stone
# 10                              Newnight
# 11  Activision (Excluding Japan and Asia)
# 12                        Electronic Arts
# 13                     Bethesda Softworks
# 14                     PlayStation PC LLC
# 15                     Gearbox Publishing
# 16                      Source Technology
# 17                             MINTROCKET
# 18                   NetEase Games Global
# 19                    Paradox Interactive
#
#                                             Languages PositiveReviews  \
# 0   English, French, German, Spanish - Spain, Poli...       (498,632)
# 1   English, Czech, Danish, Dutch, Finnish, French...     (6,845,621)
# 2                                             English       (218,847)
# 3   English, French, Italian, German, Spanish - Sp...       (564,519)
# 4   English, French, Italian, German, Spanish - Sp...       (688,189)
# 5   English, French, Italian, German, Spanish - Sp...       (613,541)
# 6   English, Bulgarian, Czech, Danish, Dutch, Finn...     (1,758,564)
# 7   English, French, Italian, German, Spanish - Sp...       (225,796)
# 8   English, French, Italian, German, Spanish - Sp...       (565,863)
# 9   English, French, Italian, German, Spanish - Sp...       (246,145)
# 10  English, French, Italian, German, Spanish - Sp...       (146,276)
# 11  English, French, Italian, German, Spanish - Sp...       (248,362)
# 12  English, French, Italian, German, Spanish - Sp...       (139,366)
# 13  English, French, German, Russian, Spanish - Sp...       (115,283)
# 14  English, French, Italian, German, Spanish - Sp...       (113,838)
# 15  English, French, Italian, German, Spanish - Sp...        (37,246)
# 16  English, Simplified Chinese, Traditional Chine...        (26,543)
# 17  English, Korean, Japanese, Simplified Chinese,...        (80,998)
# 18  English, Simplified Chinese, Traditional Chine...       (159,091)
# 19  English, French, German, Spanish - Spain, Poli...       (140,471)
#
#    TotalReviews NegativeReviews  OriginalPrice  DiscountPercent  \
# 0     (515,427)        (16,795)       990000.0             0.10
# 1   (7,809,836)       (964,215)            0.0             0.00
# 2     (222,992)         (4,145)       142000.0             0.00
# 3     (697,970)       (133,451)       990000.0             0.50
# 4     (744,999)        (56,810)       898000.0             0.40
# 5     (773,739)       (160,198)            0.0             0.00
# 6   (2,142,374)       (383,810)            0.0             0.00
# 7     (245,819)        (20,023)      1290000.0             0.50
# 8     (704,111)       (138,248)       230000.0             0.65
# 9     (261,675)        (15,530)       260000.0             0.33
# 10    (171,130)        (24,854)       385000.0             0.20
# 11    (260,507)        (12,145)      1290000.0             0.50
# 12    (146,320)         (6,954)       790000.0             0.75
# 13    (141,088)        (25,805)       450000.0             0.70
# 14    (117,594)         (3,756)      1159000.0             0.50
# 15     (43,992)         (6,746)       830000.0             0.40
# 16     (36,220)         (9,677)       310000.0             0.30
# 17     (83,021)         (2,023)       260000.0             0.20
# 18    (233,803)        (74,712)            0.0             0.00
# 19    (158,654)        (18,183)       400000.0             0.70
#
#     DiscountedPrice
# 0          891000.0
# 1               0.0
# 2          142000.0
# 3          495000.0
# 4          538800.0
# 5               0.0
# 6               0.0
# 7          645000.0
# 8           80500.0
# 9          174200.0
# 10         308000.0
# 11         645000.0
# 12         197500.0
# 13         135000.0
# 14         579500.0
# 15         498000.0
# 16         217000.0
# 17         208000.0
# 18              0.0
# 19         120000.0

# %% [markdown]
# #### Vì cột Franchise chứa quá nhiều dữ liệu bị thiếu (hơn 50%), nhưng lại không thể "fill" giá trị ngẫu nhiêu nào, hay có giá trị đặc thù nào có thể thay thế những dữ liệu bị thiếu mà không gây nhiễu
#
# Nên ta chọn loại bỏ hẳn cột này ra khỏi dataframe

# %%
df.drop(columns = ['Franchise'], inplace = True)

# %%
df.head(15)
# Out:
#                                         Title  \
# 0                             Baldur's Gate 3
# 1                            Counter-Strike 2
# 2                              Lethal Company
# 3                              Cyberpunk 2077
# 4                                  ELDEN RING
# 5                               Apex Legends™
# 6                                      Dota 2
# 7                             Hogwarts Legacy
# 8                            Dead by Daylight
# 9                             Project Zomboid
# 10                         Sons Of The Forest
# 11  Sekiro™: Shadows Die Twice - GOTY Edition
# 12                               It Takes Two
# 13                  The Elder Scrolls® Online
# 14                                 God of War
#
#                                                 Genre  \
# 0                            Adventure, RPG, Strategy
# 1                                Action, Free to Play
# 2              Action, Adventure, Indie, Early Access
# 3                                                 RPG
# 4                                         Action, RPG
# 5                     Action, Adventure, Free to Play
# 6                      Action, Strategy, Free to Play
# 7                              Action, Adventure, RPG
# 8                                              Action
# 9                Indie, RPG, Simulation, Early Access
# 10  Action, Adventure, Indie, Simulation, Early Ac...
# 11                                  Action, Adventure
# 12                                  Action, Adventure
# 13      Action, Adventure, Massively Multiplayer, RPG
# 14                             Action, Adventure, RPG
#
#                                                  Tags  withDLC  isMature  \
# 0   RPG, Choices Matter, Story Rich, Character Cus...      1.0       1.0
# 1   FPS, Shooter, Multiplayer, Competitive, Action...      1.0       1.0
# 2   Online Co-Op, Horror, First-Person, Psychologi...      0.0       1.0
# 3   Cyberpunk, Open World, Nudity, RPG, Singleplay...      1.0       1.0
# 4   Souls-like, Dark Fantasy, Open World, RPG, Dif...      0.0       1.0
# 5   Free to Play, Battle Royale, Multiplayer, Shoo...      0.0       0.0
# 6   Free to Play, MOBA, Multiplayer, Strategy, eSp...      1.0       0.0
# 7   Magic, Fantasy, Open World, Singleplayer, Adve...      1.0       0.0
# 8   Horror, Survival Horror, Multiplayer, Online C...      1.0       1.0
# 9   Survival, Zombies, Open World, Open World Surv...      0.0       0.0
# 10  Survival, Open World, Multiplayer, Survival Ho...      0.0       1.0
# 11  Souls-like, Difficult, Action, Singleplayer, N...      0.0       1.0
# 12  Co-op, Multiplayer, Split Screen, Local Co-Op,...      0.0       0.0
# 13  RPG, MMORPG, Open World, Adventure, Fantasy, E...      1.0       1.0
# 14  Action, Singleplayer, Story Rich, Adventure, M...      0.0       1.0
#
#      ReleaseDate                   Developer  \
# 0    3 Aug, 2023              Larian Studios
# 1   21 Aug, 2012                       Valve
# 2   23 Oct, 2023                    Zeekerss
# 3    9 Dec, 2020              CD PROJEKT RED
# 4   24 Feb, 2022           FromSoftware Inc.
# 5    4 Nov, 2020       Respawn Entertainment
# 6    9 Jul, 2013                       Valve
# 7   10 Feb, 2023          Avalanche Software
# 8   14 Jun, 2016  Behaviour Interactive Inc.
# 9    8 Nov, 2013             The Indie Stone
# 10  23 Feb, 2023          Endnight Games Ltd
# 11  21 Mar, 2019                FromSoftware
# 12  25 Mar, 2021                   Hazelight
# 13   4 Apr, 2014      ZeniMax Online Studios
# 14  14 Jan, 2022         Santa Monica Studio
#
#                                 Publisher  \
# 0                          Larian Studios
# 1                                   Valve
# 2                                Zeekerss
# 3                          CD PROJEKT RED
# 4                       FromSoftware Inc.
# 5                         Electronic Arts
# 6                                   Valve
# 7                      Warner Bros. Games
# 8              Behaviour Interactive Inc.
# 9                         The Indie Stone
# 10                              Newnight
# 11  Activision (Excluding Japan and Asia)
# 12                        Electronic Arts
# 13                     Bethesda Softworks
# 14                     PlayStation PC LLC
#
#                                             Languages PositiveReviews  \
# 0   English, French, German, Spanish - Spain, Poli...       (498,632)
# 1   English, Czech, Danish, Dutch, Finnish, French...     (6,845,621)
# 2                                             English       (218,847)
# 3   English, French, Italian, German, Spanish - Sp...       (564,519)
# 4   English, French, Italian, German, Spanish - Sp...       (688,189)
# 5   English, French, Italian, German, Spanish - Sp...       (613,541)
# 6   English, Bulgarian, Czech, Danish, Dutch, Finn...     (1,758,564)
# 7   English, French, Italian, German, Spanish - Sp...       (225,796)
# 8   English, French, Italian, German, Spanish - Sp...       (565,863)
# 9   English, French, Italian, German, Spanish - Sp...       (246,145)
# 10  English, French, Italian, German, Spanish - Sp...       (146,276)
# 11  English, French, Italian, German, Spanish - Sp...       (248,362)
# 12  English, French, Italian, German, Spanish - Sp...       (139,366)
# 13  English, French, German, Russian, Spanish - Sp...       (115,283)
# 14  English, French, Italian, German, Spanish - Sp...       (113,838)
#
#    TotalReviews NegativeReviews  OriginalPrice  DiscountPercent  \
# 0     (515,427)        (16,795)       990000.0             0.10
# 1   (7,809,836)       (964,215)            0.0             0.00
# 2     (222,992)         (4,145)       142000.0             0.00
# 3     (697,970)       (133,451)       990000.0             0.50
# 4     (744,999)        (56,810)       898000.0             0.40
# 5     (773,739)       (160,198)            0.0             0.00
# 6   (2,142,374)       (383,810)            0.0             0.00
# 7     (245,819)        (20,023)      1290000.0             0.50
# 8     (704,111)       (138,248)       230000.0             0.65
# 9     (261,675)        (15,530)       260000.0             0.33
# 10    (171,130)        (24,854)       385000.0             0.20
# 11    (260,507)        (12,145)      1290000.0             0.50
# 12    (146,320)         (6,954)       790000.0             0.75
# 13    (141,088)        (25,805)       450000.0             0.70
# 14    (117,594)         (3,756)      1159000.0             0.50
#
#     DiscountedPrice
# 0          891000.0
# 1               0.0
# 2          142000.0
# 3          495000.0
# 4          538800.0
# 5               0.0
# 6               0.0
# 7          645000.0
# 8           80500.0
# 9          174200.0
# 10         308000.0
# 11         645000.0
# 12         197500.0
# 13         135000.0
# 14         579500.0

# %%
def format_reviews_col(review):
    regex = r'[(),]'
    # review = review.replace('.0', '')
    replacement = re.sub(regex, '', str(review))
    return replacement

cols_review = ['PositiveReviews', 'TotalReviews', 'NegativeReviews']
df[cols_review] = df[cols_review].applymap(format_reviews_col)
df[cols_review] = df[cols_review].astype(np.float64)

# %%
df[cols_review]
# Out:
#       PositiveReviews  TotalReviews  NegativeReviews
# 0            498632.0      515427.0          16795.0
# 1           6845621.0     7809836.0         964215.0
# 2            218847.0      222992.0           4145.0
# 3            564519.0      697970.0         133451.0
# 4            688189.0      744999.0          56810.0
# ...               ...           ...              ...
# 9578             84.0         101.0             17.0
# 9579            372.0         453.0             81.0
# 9580            142.0         191.0             49.0
# 9581             57.0          61.0              4.0
# 9582            221.0         246.0             25.0
#
# [9531 rows x 3 columns]

# %% [markdown]
# ##### Kiểm tra tính toàn vẹn dữ liệu, ta sẽ tính tổng cột positive và negative reviews có bằng giá trị ở cột Total review hay không?

# %%
check_review_cols = (df['NegativeReviews'] + df['PositiveReviews'] == df['TotalReviews']).sum()
check_sum = check_review_cols.sum()
if check_sum == df.shape[0]:
    print('Data in Review columns are good !!!')
else:
    print('Have to update the value in Positive or Negative review using Total and another')
# Out:
# Have to update the value in Positive or Negative review using Total and another

# %% [markdown]
# #### Kiểm tra dữ liệu ở cột *Release Date*, nếu giá trị là Nan, đồng nghĩa với trò chơi điện tử này chưa được phát hành chính thức nên xóa khỏi dataframe

# %%
df.dropna(subset = 'ReleaseDate', inplace = True)

# %% [markdown]
# ##### Chuyển cột *ReleaseDate* về kiểu datetime

# %%
def convert_to_datetime(date_str):
    formats = [r'%b %d, %Y', r'%d %b, %Y', r'%b %Y']
    for format in formats:
        try:
            return dt.strptime(date_str, format)
        except ValueError:
            pass
    return np.nan

df['ReleaseDate'] = df['ReleaseDate'].apply(convert_to_datetime)

# %%
# for date in df['ReleaseDate']:
#     print(date)

# %%
type(df['ReleaseDate'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9526 entries, 0 to 9582
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            9526 non-null   object
#  1   Genre            9510 non-null   object
#  2   Tags             9526 non-null   object
#  3   withDLC          9526 non-null   float64
#  4   isMature         9526 non-null   float64
#  5   ReleaseDate      9525 non-null   datetime64[ns]
#  6   Developer        9520 non-null   object
#  7   Publisher        9504 non-null   object
#  8   Languages        9526 non-null   object
#  9   PositiveReviews  9513 non-null   float64
#  10  TotalReviews     9513 non-null   float64
#  11  NegativeReviews  9513 non-null   float64
#  12  OriginalPrice    9526 non-null   float64
#  13  DiscountPercent  9526 non-null   float64
#  14  DiscountedPrice  9526 non-null   float64
# dtypes: datetime64[ns](1), float64(8), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Kiểm tra sự trùng lặp dữ liệu trước khi tính Rating cho từng trò chơi điện tử
# Sự trùng lặp sẽ dựa trên cột **Title**, nếu có sự trùng lặp thì tiến hành loại bỏ và giữ lại sự xuất hiện đầu tiên

# %%
num_duplicated_rows = df.duplicated('Title').sum()
if num_duplicated_rows == 0:
    print('Data is good with no duplicated rows')
else:
    print('Drop duplicated rows, but keep first occurence')

df.drop_duplicates(keep = 'first', inplace = True)
# Out:
# Drop duplicated rows, but keep first occurence

# %% [markdown]
# Ta thử kiếm tra lại xem còn cột nào chứa missing value không:

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# Title              0.000000
# Genre              0.172618
# Tags               0.000000
# withDLC            0.000000
# isMature           0.000000
# ReleaseDate        0.010789
# Developer          0.064732
# Publisher          0.226562
# Languages          0.000000
# PositiveReviews    0.140252
# TotalReviews       0.140252
# NegativeReviews    0.140252
# OriginalPrice      0.000000
# DiscountPercent    0.000000
# DiscountedPrice    0.000000
# dtype: float64

# %% [markdown]
# Missing value ở các thuộc tính `Genre`, `Developer` và `Publisher` vẫn còn, tuy nhiên số lượng không đáng kể nên ta có thể fill các dòng này:

# %%
df['Genre'].fillna(df['Genre'].mode().values[0], inplace=True)
df['Developer'].fillna(df['Developer'].mode().values[0], inplace=True)
df['Publisher'].fillna(df['Publisher'].mode().values[0], inplace=True)
df['ReleaseDate'].fillna(df['ReleaseDate'].mode().values[0], inplace=True)
df['Languages'].fillna(df['Languages'].mode().values[0], inplace=True)
df['PositiveReviews'].fillna(df['PositiveReviews'].mode().values[0], inplace=True)
df['TotalReviews'].fillna(df['TotalReviews'].mode().values[0], inplace=True)
df['NegativeReviews'].fillna(df['NegativeReviews'].mode().values[0], inplace=True)

# %% [markdown]
# Kiểm tra thêm một lần nữa:

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# Title              0.0
# Genre              0.0
# Tags               0.0
# withDLC            0.0
# isMature           0.0
# ReleaseDate        0.0
# Developer          0.0
# Publisher          0.0
# Languages          0.0
# PositiveReviews    0.0
# TotalReviews       0.0
# NegativeReviews    0.0
# OriginalPrice      0.0
# DiscountPercent    0.0
# DiscountedPrice    0.0
# dtype: float64

# %% [markdown]
# Vậy là giờ dữ liệu không còn chứa missing value nữa.

# %% [markdown]
# # Phân tích cột dữ liệu số (numerical feature)

# %%
numeric_df = df.select_dtypes(include='number')
numeric_df.describe()
# Out:
#            withDLC     isMature  PositiveReviews  TotalReviews  \
# count  9269.000000  9269.000000     9.269000e+03  9.269000e+03
# mean      0.449563     0.218254     8.497340e+03  9.664013e+03
# std       0.497476     0.413083     8.242057e+04  9.349747e+04
# min       0.000000     0.000000     6.000000e+00  9.000000e+00
# 25%       0.000000     0.000000     2.140000e+02  2.550000e+02
# 50%       0.000000     0.000000     7.590000e+02  9.010000e+02
# 75%       1.000000     0.000000     3.060000e+03  3.605000e+03
# max       1.000000     1.000000     6.845621e+06  7.809836e+06
#
#        NegativeReviews  OriginalPrice  DiscountPercent  DiscountedPrice
# count      9269.000000   9.269000e+03      9269.000000     9.269000e+03
# mean       1166.707628   2.366783e+05         0.444999     1.210667e+05
# std       11853.418491   2.129635e+05         0.270401     1.361701e+05
# min           0.000000   0.000000e+00         0.000000     0.000000e+00
# 25%          27.000000   1.200000e+05         0.250000     4.625000e+04
# 50%         111.000000   1.880000e+05         0.500000     8.460000e+04
# 75%         470.000000   2.600000e+05         0.700000     1.505000e+05
# max      964215.000000   2.400000e+06         0.980000     2.400000e+06

# %% [markdown]
# ### Quan sát bảng mô tả số liệu ta thấy:
# - Ta thấy trong dữ liệu sau khi loại bỏ các missing value thì còn 1728 dòng.
# - Số điểm trung bình của tất cả các game là xấp xỉ 0.9, số điểm thấp nhất là 0.76, và cao nhất là 0.97.

# %% [markdown]
# ### Kiểm tra xem dữ liệu có giá những giá trị ngoại lai `outliers` không:

# %%
plt.figure(figsize=(40,90))
df[['PositiveReviews', 'NegativeReviews', 'TotalReviews', 'OriginalPrice', 'DiscountedPrice', 'DiscountPercent']].plot(kind='box')
plt.show()

# %% [markdown]
# Ta thấy những giá trị này có một số `outliers`. Giờ ta sẽ tiến hành xóa các dòng chứa giá trị này

# %%
# Hàm loại bỏ giá trị ngoại lai
def outlier_detection_iqr(temp_df, feature):
    outlier_rows = []
    Q1 = np.percentile(temp_df[feature], 25)
    Q3 = np.percentile(temp_df[feature], 75)
    IQR = Q3 - Q1
    IQR_range = 1.5 * IQR
    
    return temp_df[(temp_df[feature] > Q1 - IQR_range) & (temp_df[feature] < Q3 + IQR_range)]

# %% [markdown]
# Xóa các outliers:

# %%
numeric_cols = ['PositiveReviews', 'NegativeReviews', 'TotalReviews', 'OriginalPrice', 'DiscountedPrice', 'DiscountPercent']
for col in numeric_cols:
    df = outlier_detection_iqr(df, col)
df.reset_index(inplace=True, drop=True)
plt.figure(figsize=(40,90))
df[['PositiveReviews', 'NegativeReviews', 'TotalReviews', 'OriginalPrice', 'DiscountedPrice', 'DiscountPercent']].plot(kind='box')
plt.show()

# %% [markdown]
# ### Kiểm tra xem có bao nhiêu thể loại (Genre) từ những game ta đọc được?
# - Việc này sẽ giúp ta lựa chọn kiểu encoding cho các dữ liệu categorical một cách hợp lí.

# %% [markdown]
# Trước hết ta sẽ kiểm tra xem những giá trị unique trong `Genre`:

# %%
def get_unique_values(feature):
    temp = df[feature]
    feature_as_str = ', '.join(temp).split(', ')
    feature_as_str = set(feature_as_str)
    return len(feature_as_str)

# %% [markdown]
# Lấy số lượng các unique `Genre`:

# %%
unique_genres = get_unique_values('Genre')
print(f'Số lượng unique genre: {unique_genres}')
# Out:
# Số lượng unique genre: 15

# %% [markdown]
# Ta thử kiểm tra xem những genre được phân bố như thế nào:

# %%
def get_distributed_cat(feature):
    temp = df[feature]
    feature_as_str = ', '.join(temp).split(', ')
    distributed_dict = {}
    
    for index, item in temp.items():
        
        for element in item.split(', '):
            if element in distributed_dict:
                # If this tag already existed in the dictionary, increase the count
                distributed_dict[element] += 1
            else:
                # Else add the tag in the dictionary with count 1
                distributed_dict[element] = 1
        
    return distributed_dict

# %%
distributed_genre = get_distributed_cat('Genre')
distributed_genre = dict(sorted(distributed_genre.items(), key=lambda item: item[1],reverse=True))
print(distributed_genre)
f, ax = plt.subplots(figsize=(6, 15))
plt.title("Phân bố genre")
sns.barplot(x=list(distributed_genre.values()), y=list(distributed_genre.keys()), ax=ax)
# Out:
# {'Indie': 3734, 'Adventure': 2624, 'Action': 2279, 'Casual': 1811, 'Simulation': 1568, 'RPG': 1455, 'Strategy': 1440, 'Early Access': 639, 'Sports': 251, 'Racing': 197, 'Free to Play': 191, 'Massively Multiplayer': 141, 'Utilities': 2, 'Audio Production': 1, 'Education': 1}
# <Axes: title={'center': 'Phân bố genre'}>

# %% [markdown]
# Nhìn trên biểu đồ, ta thấy số lượng game có genre là `Indie` chiếm rất nhiều, trong khi đó một số genre chỉ được chỉ có trong 1 game mà chúng ta đã thu thập.
#
# Tiếp theo ta thử kiểm tra số lượng các `Tags` như thế nào:

# %%
unique_tags = get_unique_values('Tags')
print(f'Số lượng unique tag: {unique_tags}')
# Out:
# Số lượng unique tag: 438

# %% [markdown]
# Số lượng tag là 358, quá nhiều để thể hiện lên trên biểu đồ. Do đó ta sẽ chỉ lấy những tag có phân bố lớn nhất (khoảng 20) để vẽ biểu đồ:

# %%
distributed_tag = get_distributed_cat('Tags')
distributed_tag = dict(sorted(distributed_tag.items(), key=lambda item: item[1], reverse=True))
# print(distributed_tag)
f, ax = plt.subplots(figsize=(6, 15))
plt.title("Phân bố tag")
sns.barplot(x=list(distributed_tag.values())[:20], y=list(distributed_tag.keys())[:20], ax=ax)
# Out:
# <Axes: title={'center': 'Phân bố tag'}>

# %% [markdown]
# Theo như quan sát và tìm hiểu, thì `Genre` được phân loại theo đặc trưng chính và tổng quát của game, còn `Tags` là phân loại theo các yếu tố, nội dung trong game một cách chi tiết hơn.\
# Hơn nữa do số lượng tag quá lớn có thể dẫn đến khó encode và ảnh hưởng đến hiệu năng của mô hình, ta nên drop nó và chỉ cần giữ lại `Genre`.

# %%
df.drop('Tags', axis=1, inplace=True)
df
# Out:
#                        Title  \
# 0                   HumanitZ
# 1                    Ratopia
# 2                  Void Crew
# 3               Bread & Fred
# 4            Mind Over Magic
# ...                      ...
# 5896            Furry Boss 💼
# 5897  Khimera: Puzzle Island
# 5898                HeXen II
# 5899           Time Commando
# 5900             DREAM LOGIC
#
#                                                   Genre  withDLC  isMature  \
# 0                  Action, Adventure, RPG, Early Access      0.0       0.0
# 1     Adventure, Casual, Indie, Simulation, Strategy...      1.0       0.0
# 2                       Action, Adventure, Early Access      0.0       0.0
# 3                      Action, Adventure, Casual, Indie      1.0       0.0
# 4                              Simulation, Early Access      0.0       0.0
# ...                                                 ...      ...       ...
# 5896               Adventure, Casual, Indie, Simulation      1.0       1.0
# 5897                           Adventure, Casual, Indie      1.0       0.0
# 5898                                             Action      0.0       0.0
# 5899                                             Action      0.0       0.0
# 5900                                   Adventure, Indie      0.0       1.0
#
#      ReleaseDate           Developer             Publisher  \
# 0     2023-09-18     Yodubzz Studios         Freedom Games
# 1     2023-11-05        Cassel Games          Cassel Games
# 2     2023-09-07      Hutlihut Games   Focus Entertainment
# 3     2023-05-23  SandCastles Studio  Apogee Entertainment
# 4     2023-12-14         Sparkypants       Klei Publishing
# ...          ...                 ...                   ...
# 5896  2023-12-02     Dirty Fox Games       Dirty Fox Games
# 5897  2020-11-29     Suits & Sandals       Suits & Sandals
# 5898  1998-03-27      Raven Software           id Software
# 5899  1996-07-31              [2.21]                [2.21]
# 5900  2022-09-06     Teleopsia Games       Teleopsia Games
#
#                                               Languages  PositiveReviews  \
# 0     English, French, German, Spanish - Spain, Japa...           1581.0
# 1     English, Korean, Japanese, Simplified Chinese,...           1602.0
# 2     English, French, German, Spanish - Spain, Poli...           2071.0
# 3     English, Spanish - Spain, Catalan, French, Ita...           2332.0
# 4                           English, Simplified Chinese            583.0
# ...                                                 ...              ...
# 5896                                            English             18.0
# 5897                                  English, Japanese            184.0
# 5898                                            English            372.0
# 5899                                            English             57.0
# 5900                                            English            221.0
#
#       TotalReviews  NegativeReviews  OriginalPrice  DiscountPercent  \
# 0           2081.0            500.0       260000.0             0.20
# 1           1807.0            205.0       260000.0             0.10
# 2           2280.0            209.0       286000.0             0.20
# 3           2644.0            312.0       205000.0             0.25
# 4            632.0             49.0       220000.0             0.10
# ...            ...              ...            ...              ...
# 5896          18.0              0.0        73500.0             0.00
# 5897         190.0              6.0        73500.0             0.90
# 5898         453.0             81.0       112500.0             0.70
# 5899          61.0              4.0        87500.0             0.00
# 5900         246.0             25.0        73500.0             0.00
#
#       DiscountedPrice
# 0            208000.0
# 1            234000.0
# 2            228800.0
# 3            153750.0
# 4            198000.0
# ...               ...
# 5896          73500.0
# 5897           7350.0
# 5898          33750.0
# 5899          87500.0
# 5900          73500.0
#
# [5901 rows x 14 columns]

# %% [markdown]
# ### Số hóa các feature

# %% [markdown]
# Ở đây, ta sẽ bắt đầu số hóa các dữ liệu category, datetime và boolean để chuẩn bị cho huấn luyện mô hình
#
# Đầu tiên là số hóa cột datetime và boolean:

# %%
df[['withDLC', 'isMature']] = df[['withDLC', 'isMature']].replace({True: 1, False: 0})
df['ReleaseYear'] = df['ReleaseDate'].dt.year
df['ReleaseMonth'] = df['ReleaseDate'].dt.month
df['ReleaseDay'] = df['ReleaseDate'].dt.day

# %% [markdown]
# Sau khi số hóa cột datetime, ta tiến hành drop cột `ReleaseDate`:

# %%
df.drop('ReleaseDate', axis=1, inplace=True)
df
# Out:
#                        Title  \
# 0                   HumanitZ
# 1                    Ratopia
# 2                  Void Crew
# 3               Bread & Fred
# 4            Mind Over Magic
# ...                      ...
# 5896            Furry Boss 💼
# 5897  Khimera: Puzzle Island
# 5898                HeXen II
# 5899           Time Commando
# 5900             DREAM LOGIC
#
#                                                   Genre  withDLC  isMature  \
# 0                  Action, Adventure, RPG, Early Access      0.0       0.0
# 1     Adventure, Casual, Indie, Simulation, Strategy...      1.0       0.0
# 2                       Action, Adventure, Early Access      0.0       0.0
# 3                      Action, Adventure, Casual, Indie      1.0       0.0
# 4                              Simulation, Early Access      0.0       0.0
# ...                                                 ...      ...       ...
# 5896               Adventure, Casual, Indie, Simulation      1.0       1.0
# 5897                           Adventure, Casual, Indie      1.0       0.0
# 5898                                             Action      0.0       0.0
# 5899                                             Action      0.0       0.0
# 5900                                   Adventure, Indie      0.0       1.0
#
#                Developer             Publisher  \
# 0        Yodubzz Studios         Freedom Games
# 1           Cassel Games          Cassel Games
# 2         Hutlihut Games   Focus Entertainment
# 3     SandCastles Studio  Apogee Entertainment
# 4            Sparkypants       Klei Publishing
# ...                  ...                   ...
# 5896     Dirty Fox Games       Dirty Fox Games
# 5897     Suits & Sandals       Suits & Sandals
# 5898      Raven Software           id Software
# 5899              [2.21]                [2.21]
# 5900     Teleopsia Games       Teleopsia Games
#
#                                               Languages  PositiveReviews  \
# 0     English, French, German, Spanish - Spain, Japa...           1581.0
# 1     English, Korean, Japanese, Simplified Chinese,...           1602.0
# 2     English, French, German, Spanish - Spain, Poli...           2071.0
# 3     English, Spanish - Spain, Catalan, French, Ita...           2332.0
# 4                           English, Simplified Chinese            583.0
# ...                                                 ...              ...
# 5896                                            English             18.0
# 5897                                  English, Japanese            184.0
# 5898                                            English            372.0
# 5899                                            English             57.0
# 5900                                            English            221.0
#
#       TotalReviews  NegativeReviews  OriginalPrice  DiscountPercent  \
# 0           2081.0            500.0       260000.0             0.20
# 1           1807.0            205.0       260000.0             0.10
# 2           2280.0            209.0       286000.0             0.20
# 3           2644.0            312.0       205000.0             0.25
# 4            632.0             49.0       220000.0             0.10
# ...            ...              ...            ...              ...
# 5896          18.0              0.0        73500.0             0.00
# 5897         190.0              6.0        73500.0             0.90
# 5898         453.0             81.0       112500.0             0.70
# 5899          61.0              4.0        87500.0             0.00
# 5900         246.0             25.0        73500.0             0.00
#
#       DiscountedPrice  ReleaseYear  ReleaseMonth  ReleaseDay
# 0            208000.0         2023             9          18
# 1            234000.0         2023            11           5
# 2            228800.0         2023             9           7
# 3            153750.0         2023             5          23
# 4            198000.0         2023            12          14
# ...               ...          ...           ...         ...
# 5896          73500.0         2023            12           2
# 5897           7350.0         2020            11          29
# 5898          33750.0         1998             3          27
# 5899          87500.0         1996             7          31
# 5900          73500.0         2022             9           6
#
# [5901 rows x 16 columns]

# %% [markdown]
# Kiểm tra những ngôn ngữ phổ biến trong game:

# %%
distributed_lan = get_distributed_cat('Languages')
distributed_lan = dict(sorted(distributed_lan.items(), key=lambda item: item[1], reverse=True))
# print(distributed_tag)
f, ax = plt.subplots(figsize=(6, 15))
plt.title("Tính phân bố các ngôn ngữ trong dữ liệu")
sns.barplot(x=list(distributed_lan.values()), y=list(distributed_lan.keys()), ax=ax)
# Out:
# <Axes: title={'center': 'Tính phân bố các ngôn ngữ trong dữ liệu'}>

# %% [markdown]
# Như ta thấy, `English` vẫn là ngôn ngữ chính trong hầu hết các game, và hầu hết người chơi nếu không có ngôn ngữ bản địa sẽ sử dụng `English` là chủ yếu, và nếu không có `English` hay ngôn ngữ bản địa của họ, sẽ khó để game đó có thể tiếp cận đến người dùng, ảnh hưởng đến đánh giá của game.\
# Do đó, ta có thể chỉ cần tạo một cột kiểm tra xem có ngôn ngữ `English` hay không:

# %%
df['HasEnglish'] = df['Languages'].apply(lambda x: 1 if 'English' in x.split(', ') else 0)
df.drop('Languages', axis=1, inplace=True)
df
# Out:
#                        Title  \
# 0                   HumanitZ
# 1                    Ratopia
# 2                  Void Crew
# 3               Bread & Fred
# 4            Mind Over Magic
# ...                      ...
# 5896            Furry Boss 💼
# 5897  Khimera: Puzzle Island
# 5898                HeXen II
# 5899           Time Commando
# 5900             DREAM LOGIC
#
#                                                   Genre  withDLC  isMature  \
# 0                  Action, Adventure, RPG, Early Access      0.0       0.0
# 1     Adventure, Casual, Indie, Simulation, Strategy...      1.0       0.0
# 2                       Action, Adventure, Early Access      0.0       0.0
# 3                      Action, Adventure, Casual, Indie      1.0       0.0
# 4                              Simulation, Early Access      0.0       0.0
# ...                                                 ...      ...       ...
# 5896               Adventure, Casual, Indie, Simulation      1.0       1.0
# 5897                           Adventure, Casual, Indie      1.0       0.0
# 5898                                             Action      0.0       0.0
# 5899                                             Action      0.0       0.0
# 5900                                   Adventure, Indie      0.0       1.0
#
#                Developer             Publisher  PositiveReviews  TotalReviews  \
# 0        Yodubzz Studios         Freedom Games           1581.0        2081.0
# 1           Cassel Games          Cassel Games           1602.0        1807.0
# 2         Hutlihut Games   Focus Entertainment           2071.0        2280.0
# 3     SandCastles Studio  Apogee Entertainment           2332.0        2644.0
# 4            Sparkypants       Klei Publishing            583.0         632.0
# ...                  ...                   ...              ...           ...
# 5896     Dirty Fox Games       Dirty Fox Games             18.0          18.0
# 5897     Suits & Sandals       Suits & Sandals            184.0         190.0
# 5898      Raven Software           id Software            372.0         453.0
# 5899              [2.21]                [2.21]             57.0          61.0
# 5900     Teleopsia Games       Teleopsia Games            221.0         246.0
#
#       NegativeReviews  OriginalPrice  DiscountPercent  DiscountedPrice  \
# 0               500.0       260000.0             0.20         208000.0
# 1               205.0       260000.0             0.10         234000.0
# 2               209.0       286000.0             0.20         228800.0
# 3               312.0       205000.0             0.25         153750.0
# 4                49.0       220000.0             0.10         198000.0
# ...               ...            ...              ...              ...
# 5896              0.0        73500.0             0.00          73500.0
# 5897              6.0        73500.0             0.90           7350.0
# 5898             81.0       112500.0             0.70          33750.0
# 5899              4.0        87500.0             0.00          87500.0
# 5900             25.0        73500.0             0.00          73500.0
#
#       ReleaseYear  ReleaseMonth  ReleaseDay  HasEnglish
# 0            2023             9          18           1
# 1            2023            11           5           1
# 2            2023             9           7           1
# 3            2023             5          23           1
# 4            2023            12          14           1
# ...           ...           ...         ...         ...
# 5896         2023            12           2           1
# 5897         2020            11          29           1
# 5898         1998             3          27           1
# 5899         1996             7          31           1
# 5900         2022             9           6           1
#
# [5901 rows x 16 columns]

# %% [markdown]
# Kiểm tra xem cột `HasEnglish` có giá trị khác 1 không:

# %%
df[df['HasEnglish'] != 1]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, withDLC, isMature, Developer, Publisher, PositiveReviews, TotalReviews, NegativeReviews, OriginalPrice, DiscountPercent, DiscountedPrice, ReleaseYear, ReleaseMonth, ReleaseDay, HasEnglish]
# Index: []

# %% [markdown]
# Không có game nào là không có `English`, Do đó cột này không có giá trị gì để tính điểm.\
# Ta sẽ loại bỏ cột này:

# %%
df.drop('HasEnglish', axis=1, inplace=True)
df
# Out:
#                        Title  \
# 0                   HumanitZ
# 1                    Ratopia
# 2                  Void Crew
# 3               Bread & Fred
# 4            Mind Over Magic
# ...                      ...
# 5896            Furry Boss 💼
# 5897  Khimera: Puzzle Island
# 5898                HeXen II
# 5899           Time Commando
# 5900             DREAM LOGIC
#
#                                                   Genre  withDLC  isMature  \
# 0                  Action, Adventure, RPG, Early Access      0.0       0.0
# 1     Adventure, Casual, Indie, Simulation, Strategy...      1.0       0.0
# 2                       Action, Adventure, Early Access      0.0       0.0
# 3                      Action, Adventure, Casual, Indie      1.0       0.0
# 4                              Simulation, Early Access      0.0       0.0
# ...                                                 ...      ...       ...
# 5896               Adventure, Casual, Indie, Simulation      1.0       1.0
# 5897                           Adventure, Casual, Indie      1.0       0.0
# 5898                                             Action      0.0       0.0
# 5899                                             Action      0.0       0.0
# 5900                                   Adventure, Indie      0.0       1.0
#
#                Developer             Publisher  PositiveReviews  TotalReviews  \
# 0        Yodubzz Studios         Freedom Games           1581.0        2081.0
# 1           Cassel Games          Cassel Games           1602.0        1807.0
# 2         Hutlihut Games   Focus Entertainment           2071.0        2280.0
# 3     SandCastles Studio  Apogee Entertainment           2332.0        2644.0
# 4            Sparkypants       Klei Publishing            583.0         632.0
# ...                  ...                   ...              ...           ...
# 5896     Dirty Fox Games       Dirty Fox Games             18.0          18.0
# 5897     Suits & Sandals       Suits & Sandals            184.0         190.0
# 5898      Raven Software           id Software            372.0         453.0
# 5899              [2.21]                [2.21]             57.0          61.0
# 5900     Teleopsia Games       Teleopsia Games            221.0         246.0
#
#       NegativeReviews  OriginalPrice  DiscountPercent  DiscountedPrice  \
# 0               500.0       260000.0             0.20         208000.0
# 1               205.0       260000.0             0.10         234000.0
# 2               209.0       286000.0             0.20         228800.0
# 3               312.0       205000.0             0.25         153750.0
# 4                49.0       220000.0             0.10         198000.0
# ...               ...            ...              ...              ...
# 5896              0.0        73500.0             0.00          73500.0
# 5897              6.0        73500.0             0.90           7350.0
# 5898             81.0       112500.0             0.70          33750.0
# 5899              4.0        87500.0             0.00          87500.0
# 5900             25.0        73500.0             0.00          73500.0
#
#       ReleaseYear  ReleaseMonth  ReleaseDay
# 0            2023             9          18
# 1            2023            11           5
# 2            2023             9           7
# 3            2023             5          23
# 4            2023            12          14
# ...           ...           ...         ...
# 5896         2023            12           2
# 5897         2020            11          29
# 5898         1998             3          27
# 5899         1996             7          31
# 5900         2022             9           6
#
# [5901 rows x 15 columns]

# %% [markdown]
# Ta thấy hai đường hồi quy phân loại theo `withDLC` và `isMature` trên mỗi hình sát nhau và gần như là một, do đó những game có **DLC** hay game có **Mature content** không ảnh hưởng quá nhiều khi người chơi đánh giá game.

# %% [markdown]
# ### Tạo cột tính điểm cho game

# %% [markdown]
# ##### Ta sẽ sử dụng công thức sau để tính score_rating cho từng trò chơi điện tử dựa trên giá trị ở các cột Reviews với miền giá trị sau khi tính sẽ là [0, 1]
# - Total Reviews = Positive Reviews + Negative Reviews
# - Review Score = Positive Reviews / Total Reviews
# - $$Rating = Review Score - (Review Score - 0.5)*2^{-log_{10}(Total Reviews + 1)}$$
#
#
# Một số lý do để sử dụng công thức này:
# 1. Tập trung vào các phản hồi tích cực, có nghĩa là mỗi phản hồi tích cực có tác động lớn hơn trên score_rating so với phản hồi tiêu cực
# 2. Mặc dù công thức tập trung và nhấn mạnh phản hồi tích cực nhưng không bỏ qua bất kì phản hồi tiêu cực nào
# 3. Có sự cân bằng khi ta cân nhắc phản hổi tích cực thật sự quan trọng hơn nhưng phản hồi tiêu cực cũng có ảnh hưởng nhất định

# %%
ReviewScore = df['PositiveReviews'] / df['TotalReviews']
df['Rating'] = ReviewScore - (ReviewScore - 0.5) * pow(2, -np.log10(df['TotalReviews'] + 1))
df
# Out:
#                        Title  \
# 0                   HumanitZ
# 1                    Ratopia
# 2                  Void Crew
# 3               Bread & Fred
# 4            Mind Over Magic
# ...                      ...
# 5896            Furry Boss 💼
# 5897  Khimera: Puzzle Island
# 5898                HeXen II
# 5899           Time Commando
# 5900             DREAM LOGIC
#
#                                                   Genre  withDLC  isMature  \
# 0                  Action, Adventure, RPG, Early Access      0.0       0.0
# 1     Adventure, Casual, Indie, Simulation, Strategy...      1.0       0.0
# 2                       Action, Adventure, Early Access      0.0       0.0
# 3                      Action, Adventure, Casual, Indie      1.0       0.0
# 4                              Simulation, Early Access      0.0       0.0
# ...                                                 ...      ...       ...
# 5896               Adventure, Casual, Indie, Simulation      1.0       1.0
# 5897                           Adventure, Casual, Indie      1.0       0.0
# 5898                                             Action      0.0       0.0
# 5899                                             Action      0.0       0.0
# 5900                                   Adventure, Indie      0.0       1.0
#
#                Developer             Publisher  PositiveReviews  TotalReviews  \
# 0        Yodubzz Studios         Freedom Games           1581.0        2081.0
# 1           Cassel Games          Cassel Games           1602.0        1807.0
# 2         Hutlihut Games   Focus Entertainment           2071.0        2280.0
# 3     SandCastles Studio  Apogee Entertainment           2332.0        2644.0
# 4            Sparkypants       Klei Publishing            583.0         632.0
# ...                  ...                   ...              ...           ...
# 5896     Dirty Fox Games       Dirty Fox Games             18.0          18.0
# 5897     Suits & Sandals       Suits & Sandals            184.0         190.0
# 5898      Raven Software           id Software            372.0         453.0
# 5899              [2.21]                [2.21]             57.0          61.0
# 5900     Teleopsia Games       Teleopsia Games            221.0         246.0
#
#       NegativeReviews  OriginalPrice  DiscountPercent  DiscountedPrice  \
# 0               500.0       260000.0             0.20         208000.0
# 1               205.0       260000.0             0.10         234000.0
# 2               209.0       286000.0             0.20         228800.0
# 3               312.0       205000.0             0.25         153750.0
# 4                49.0       220000.0             0.10         198000.0
# ...               ...            ...              ...              ...
# 5896              0.0        73500.0             0.00          73500.0
# 5897              6.0        73500.0             0.90           7350.0
# 5898             81.0       112500.0             0.70          33750.0
# 5899              4.0        87500.0             0.00          87500.0
# 5900             25.0        73500.0             0.00          73500.0
#
#       ReleaseYear  ReleaseMonth  ReleaseDay    Rating
# 0            2023             9          18  0.733696
# 1            2023            11           5  0.846123
# 2            2023             9           7  0.868512
# 3            2023             5          23  0.846368
# 4            2023            12          14  0.861866
# ...           ...           ...         ...       ...
# 5896         2023            12           2  0.793924
# 5897         2020            11          29  0.872043
# 5898         1998             3          27  0.770269
# 5899         1996             7          31  0.809010
# 5900         2022             9           6  0.822513
#
# [5901 rows x 16 columns]

# %% [markdown]
# **Tiền xử lí hoàn tất, ta xuất dữ liệu ra một file mới chuẩn bị cho giai đoạn học máy:**

# %%
df.to_csv('../data/processed_data.csv', index=False)
